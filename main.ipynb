# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # ADDITIONAL INFO
# - InvoiceNo: Invoice number. Nominal. A 6-digit integral number uniquely assigned to each transaction. If this code starts with the letter 'c', it indicates a cancellation.
# - StockCode: Product (item) code. Nominal. A 5-digit integral number uniquely assigned to each distinct product.
# - Description: Product (item) name. Nominal.
# - Quantity: The quantities of each product (item) per transaction. Numeric.
# - InvoiceDate: Invice date and time. Numeric. The day and time when a transaction was generated.
# - UnitPrice: Unit price. Numeric. Product price per unit in sterling (Â£).
# - CustomerID: Customer number. Nominal. A 5-digit integral number uniquely assigned to each customer.
# - Country: Country name. Nominal. The name of the country where a customer resides.

# %%
df = pd.read_excel("./data/online_retail_II.xlsx", engine="openpyxl")

df.head(10)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5  489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6  489434     21871                  SAVE THE PLANET MUG        24
# 7  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8  489435     22350                            CAT BOWL         12
# 9  489435     22349       DOG BOWL , CHASING BALL DESIGN        12
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.shape
# Out:
# (525461, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[us]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 32.1+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(6865)

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  525461.000000                      525461  525461.000000  417534.000000
# mean       10.337667  2010-06-28 11:37:36.845018       4.688834   15360.645478
# min     -9600.000000         2009-12-01 07:45:00  -53594.360000   12346.000000
# 25%         1.000000         2010-03-21 12:20:00       1.250000   13983.000000
# 50%         3.000000         2010-07-06 09:51:00       2.100000   15311.000000
# 75%        10.000000         2010-10-15 12:45:00       4.210000   16799.000000
# max     19152.000000         2010-12-09 20:01:00   25111.090000   18287.000000
# std       107.424110                         NaN     146.126914    1680.811316

# %%
df.describe(include='O')
# Out:
#         Invoice StockCode                         Description         Country
# count    525461    525461                              522533          525461
# unique    28816      4632                                4681              40
# top      537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq        675      3516                                3549          485852

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df[df["Customer ID"].isna()].head(10)
# Out:
#      Invoice StockCode                   Description  Quantity  \
# 263   489464     21733                  85123a mixed       -96
# 283   489463     71477                         short      -240
# 284   489467    85123A                   21733 mixed      -192
# 470   489521     21646                           NaN       -50
# 577   489525    85226C     BLUE PULL BACK RACING CAR         1
# 578   489525     85227   SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271          FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254          FELT TOADSTOOL LARGE        12
# 1057  489548     22273          FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195  LARGE HEART MEASURING SPOONS         1
#
#              InvoiceDate  Price  Customer ID         Country
# 263  2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 283  2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 284  2009-12-01 10:53:00   0.00          NaN  United Kingdom
# ...

# %%
df[df["Quantity"] < 0].head(10)
# Out:
#      Invoice StockCode                        Description  Quantity  \
# 178  C489449     22087           PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A       CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895      POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896                 POTTING SHED TWINE        -6
# 182  C489449     22083         PAPER CHAIN KIT RETRO SPOT       -12
# 183  C489449     21871                SAVE THE PLANET MUG       -12
# 184  C489449     84946    ANTIQUE SILVER TEA GLASS ETCHED       -12
# 185  C489449    84970S  HANGING HEART ZINC T-LIGHT HOLDER       -24
# 186  C489449     22090          PAPER BUNTING RETRO SPOTS       -12
# 196  C489459    90200A         PURPLE SWEETHEART BRACELET        -3
#
#             InvoiceDate  Price  Customer ID         Country
# 178 2009-12-01 10:33:00   2.95      16321.0       Australia
# 179 2009-12-01 10:33:00   1.65      16321.0       Australia
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[us]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 32.1+ MB

# %%
df["Invoice"] = df["Invoice"].astype("str")
df[df["Invoice"].str.match("^\\d{6}$") == False]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %%
df["Invoice"].str.replace("[0-9]", "", regex=True).unique()
# Out:
# <StringArray>
# ['', 'C', 'A']
# Length: 3, dtype: str

# %%
df[df["Invoice"].str.startswith("A")]
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom

# %%
df["StockCode"] = df["StockCode"].astype("str")
df[(df["StockCode"].str.match("^\\d{5}$") == False) & (df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == False)]["StockCode"].unique()
# Out:
# <StringArray>
# [        'POST',            'D',     'DCGS0058',     'DCGS0068',
#           'DOT',            'M',     'DCGS0004',     'DCGS0076',
#            'C2', 'BANK CHARGES',     'DCGS0003',      'TEST001',
#  'gift_0001_80',     'DCGS0072', 'gift_0001_20',     'DCGS0044',
#       'TEST002', 'gift_0001_10', 'gift_0001_50',    'DCGS0066N',
#  'gift_0001_30',         'PADS',       'ADJUST', 'gift_0001_40',
#  'gift_0001_60', 'gift_0001_70', 'gift_0001_90',    'DCGSSGIRL',
#      'DCGS0006',     'DCGS0016',     'DCGS0027',     'DCGS0036',
#      'DCGS0039',     'DCGS0060',     'DCGS0056',     'DCGS0059',
#          'GIFT',     'DCGSLBOY',            'm',     'DCGS0053',
#      'DCGS0062',     'DCGS0037',     'DCGSSBOY',    'DCGSLGIRL',
#             'S',     'DCGS0069',     'DCGS0070',     'DCGS0075',
#             'B',     'DCGS0041',      'ADJUST2',      '47503J ',
#            'C3',       'SP1002',    'AMAZONFEE']
# Length: 55, dtype: str

# %%
df[df["StockCode"].str.contains("^DOT")].head(10)
# Out:
#      Invoice StockCode     Description  Quantity         InvoiceDate   Price  \
# 2379  489597       DOT  DOTCOM POSTAGE         1 2009-12-01 14:28:00  647.19
# 2539  489600       DOT  DOTCOM POSTAGE         1 2009-12-01 14:43:00   55.96
# 2551  489601       DOT  DOTCOM POSTAGE         1 2009-12-01 14:44:00   68.39
# 2571  489602       DOT  DOTCOM POSTAGE         1 2009-12-01 14:45:00   59.35
# 2619  489603       DOT  DOTCOM POSTAGE         1 2009-12-01 14:46:00   42.39
# 2644  489604       DOT  DOTCOM POSTAGE         1 2009-12-01 14:47:00   50.87
# 2686  489607       DOT  DOTCOM POSTAGE         1 2009-12-01 14:49:00   76.30
# 2698  489609       DOT  DOTCOM POSTAGE         1 2009-12-01 14:50:00   74.61
# 2771  489612       DOT  DOTCOM POSTAGE         1 2009-12-01 14:55:00   87.39
# 2806  489614       DOT  DOTCOM POSTAGE         1 2009-12-01 14:56:00   80.30
#
#       Customer ID         Country
# 2379          NaN  United Kingdom
# 2539          NaN  United Kingdom
# ...

# %% [markdown]
# OBSERVATION:
# - DOT: Looks valid, represents postage charges -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^DCGS0058")].head(5)
# Out:
#       Invoice StockCode       Description  Quantity         InvoiceDate  \
# 2377   489597  DCGS0058  MISO PRETTY  GUM         1 2009-12-01 14:28:00
# 8372   490074  DCGS0058  MISO PRETTY  GUM         1 2009-12-03 14:39:00
# 17264  490745  DCGS0058  MISO PRETTY  GUM         1 2009-12-07 18:02:00
# 30671  491969  DCGS0058  MISO PRETTY  GUM         1 2009-12-14 17:57:00
# 31652  491970  DCGS0058  MISO PRETTY  GUM         1 2009-12-14 18:03:00
#
#        Price  Customer ID         Country
# 2377    0.83          NaN  United Kingdom
# 8372    0.83          NaN  United Kingdom
# 17264   0.83          NaN  United Kingdom
# 30671   0.83          NaN  United Kingdom
# 31652   0.83          NaN  United Kingdom

# %%
df[df["StockCode"].str.contains("^DCGS0068")].head(5)
# Out:
#       Invoice StockCode        Description  Quantity         InvoiceDate  \
# 2378   489597  DCGS0068  DOGS NIGHT COLLAR         1 2009-12-01 14:28:00
# 62734  494918  DCGS0068  DOGS NIGHT COLLAR         1 2010-01-19 17:49:00
#
#        Price  Customer ID         Country
# 2378    8.65          NaN  United Kingdom
# 62734   8.47          NaN  United Kingdom

# %%
df[df["StockCode"].str.contains("^DCGSSBOY")].head(5)
# Out:
#        Invoice StockCode     Description  Quantity         InvoiceDate  Price  \
# 101692  499040  DCGSSBOY             NaN       -90 2010-02-24 13:16:00   0.00
# 241371  512737  DCGSSBOY          update       100 2010-06-17 14:10:00   0.00
# 244830  513099  DCGSSBOY  BOYS PARTY BAG         5 2010-06-21 15:13:00   3.36
# 246183  513200  DCGSSBOY  BOYS PARTY BAG         7 2010-06-22 16:28:00   3.36
# 249937  513574  DCGSSBOY  BOYS PARTY BAG         3 2010-06-25 15:13:00   3.36
#
#         Customer ID         Country
# 101692          NaN  United Kingdom
# 241371          NaN  United Kingdom
# 244830          NaN  United Kingdom
# 246183          NaN  United Kingdom
# 249937          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - DCGS: Looks valid, some quantities are negative though and customer ID is null -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^D")].head(5)
# Out:
#       Invoice StockCode        Description  Quantity         InvoiceDate  \
# 735   C489535         D           Discount        -1 2009-12-01 12:11:00
# 736   C489535         D           Discount        -1 2009-12-01 12:11:00
# 2377   489597  DCGS0058   MISO PRETTY  GUM         1 2009-12-01 14:28:00
# 2378   489597  DCGS0068  DOGS NIGHT COLLAR         1 2009-12-01 14:28:00
# 2379   489597       DOT     DOTCOM POSTAGE         1 2009-12-01 14:28:00
#
#        Price  Customer ID         Country
# 735     9.00      15299.0  United Kingdom
# 736    19.00      15299.0  United Kingdom
# 2377    0.83          NaN  United Kingdom
# 2378    8.65          NaN  United Kingdom
# 2379  647.19          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - D: Looks valid, represents discount values -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^M")].head(5)
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate    Price  \
# 2697   489609         M      Manual         1 2009-12-01 14:50:00     4.00
# 3053  C489651         M      Manual        -1 2009-12-01 16:48:00     5.10
# 5897  C489859         M      Manual        -1 2009-12-02 14:45:00    69.57
# 9259  C490126         M      Manual        -1 2009-12-03 18:12:00     5.95
# 9307  C490129         M      Manual        -1 2009-12-03 18:26:00  1998.49
#
#       Customer ID         Country
# 2697          NaN  United Kingdom
# 3053      17804.0  United Kingdom
# 5897          NaN  United Kingdom
# 9259      15884.0  United Kingdom
# 9307      15482.0  United Kingdom

# %%
df[df["StockCode"].str.contains("^m")].head(5)
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 96608   498492         m      Manual         1 2010-02-19 10:56:00   2.55
# 96609   498492         m      Manual         1 2010-02-19 10:56:00   3.40
# 157226  504396         m      Manual         1 2010-04-13 11:45:00   4.00
# 228780  511509         m      Manual         1 2010-06-08 15:26:00   2.55
#
#         Customer ID         Country
# 96608           NaN  United Kingdom
# 96609           NaN  United Kingdom
# 157226          NaN  United Kingdom
# 228780          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - M/m: Looks valid, represents manual transactions -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^C2")].head(5)
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 9292   490127        C2    CARRIAGE         1 2009-12-03 18:13:00   50.0
# 14481  490541        C2    CARRIAGE         1 2009-12-07 09:25:00   50.0
# 14502  490542        C2    CARRIAGE         1 2009-12-07 09:42:00   50.0
# 19541  490998        C2    CARRIAGE         1 2009-12-08 17:24:00   50.0
# 22803  491160        C2    CARRIAGE         1 2009-12-10 10:29:00   50.0
#
#        Customer ID         Country
# 9292       14156.0            EIRE
# 14481          NaN            EIRE
# 14502      14911.0            EIRE
# 19541      16253.0  United Kingdom
# 22803      14911.0            EIRE

# %%
df[df["StockCode"].str.contains("^C3")].head(5)
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 302041  518785        C3         NaN     -4999 2010-08-11 16:55:00    0.0
#
#         Customer ID         Country
# 302041          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - C2: Carriage transaction, not sure what this means -- Exclude from clustering
# - C3: Not sure, only 1 transaction -- Exclude

# %%
df[df["StockCode"].str.contains("^BANK CHARGES")].head(5)
# Out:
#        Invoice     StockCode    Description  Quantity         InvoiceDate  \
# 18410  C490943  BANK CHARGES   Bank Charges        -1 2009-12-08 14:08:00
# 18466   490948  BANK CHARGES   Bank Charges         1 2009-12-08 14:29:00
# 33435  C492206  BANK CHARGES   Bank Charges        -1 2009-12-15 16:32:00
# 55948  C494438  BANK CHARGES   Bank Charges        -1 2010-01-14 12:15:00
# 94431   498269  BANK CHARGES   Bank Charges         1 2010-02-17 15:03:00
#
#         Price  Customer ID         Country
# 18410   15.00      16703.0  United Kingdom
# 18466   15.00      16805.0  United Kingdom
# 33435  848.43          NaN  United Kingdom
# 55948  767.99          NaN  United Kingdom
# 94431   15.00      16928.0  United Kingdom

# %%
df[df["StockCode"].str.contains("^B")].head(5)
# Out:
#        Invoice     StockCode    Description  Quantity         InvoiceDate  \
# 18410  C490943  BANK CHARGES   Bank Charges        -1 2009-12-08 14:08:00
# 18466   490948  BANK CHARGES   Bank Charges         1 2009-12-08 14:29:00
# 33435  C492206  BANK CHARGES   Bank Charges        -1 2009-12-15 16:32:00
# 55948  C494438  BANK CHARGES   Bank Charges        -1 2010-01-14 12:15:00
# 94431   498269  BANK CHARGES   Bank Charges         1 2010-02-17 15:03:00
#
#         Price  Customer ID         Country
# 18410   15.00      16703.0  United Kingdom
# 18466   15.00      16805.0  United Kingdom
# 33435  848.43          NaN  United Kingdom
# 55948  767.99          NaN  United Kingdom
# 94431   15.00      16928.0  United Kingdom

# %% [markdown]
# OBSERVATION:
# - BANK CHARGES/B: Valid, bank charges -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^S")].head(5)
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate   Price  \
# 114061  C500305         S     SAMPLES        -1 2010-03-07 10:59:00   73.80
# 114083  C500309         S     SAMPLES        -1 2010-03-07 11:09:00   32.03
# 133558  C502083         S     SAMPLES        -1 2010-03-22 15:50:00  170.37
# 133582  C502088         S     SAMPLES        -1 2010-03-22 16:03:00  259.59
# 136253  C502438         S     SAMPLES        -1 2010-03-24 13:11:00  605.18
#
#         Customer ID         Country
# 114061          NaN  United Kingdom
# 114083          NaN  United Kingdom
# 133558          NaN  United Kingdom
# 133582          NaN  United Kingdom
# 136253          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - S: Samples sent to customer, has null Customer ID -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^TEST001")].head(5)
# Out:
#       Invoice StockCode              Description  Quantity  \
# 27994  491725   TEST001  This is a test product.        10
# 28251  491742   TEST001  This is a test product.         5
# 28254  491744   TEST001  This is a test product.         5
# 39398  492718   TEST001  This is a test product.         5
# 45228  493410   TEST001  This is a test product.         5
#
#               InvoiceDate  Price  Customer ID         Country
# 27994 2009-12-14 08:34:00    4.5      12346.0  United Kingdom
# 28251 2009-12-14 11:00:00    4.5      12346.0  United Kingdom
# 28254 2009-12-14 11:02:00    4.5      12346.0  United Kingdom
# 39398 2009-12-18 10:47:00    4.5      12346.0  United Kingdom
# 45228 2010-01-04 09:24:00    4.5      12346.0  United Kingdom

# %%
df[df["StockCode"].str.contains("^TEST002")].head(5)
# Out:
#       Invoice StockCode              Description  Quantity  \
# 39411  492722   TEST002  This is a test product.         1
# 44614  493294   TEST002                      NaN         1
#
#               InvoiceDate  Price  Customer ID         Country
# 39411 2009-12-18 10:55:00    1.0      12346.0  United Kingdom
# 44614 2009-12-22 15:15:00    0.0          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - TEST: Testing data, not valid -- Exclude from clustering

# %%
df[df["StockCode"].str.contains("^gift_0001_80")].head(5)
# Out:
#         Invoice     StockCode                         Description  Quantity  \
# 30620    491968  gift_0001_80                                 NaN         2
# 31079    491969  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00         1
# 56446   C494472  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        -1
# 298842   518488  gift_0001_80                                 NaN        10
#
#                InvoiceDate  Price  Customer ID         Country
# 30620  2009-12-14 17:56:00   0.00          NaN  United Kingdom
# 31079  2009-12-14 17:57:00  69.56          NaN  United Kingdom
# 56446  2010-01-14 14:51:00  69.56          NaN  United Kingdom
# 298842 2010-08-09 12:29:00   0.00          NaN  United Kingdom

# %%
df[df["StockCode"].str.contains("^gift_0001_60")].head(5)
# Out:
#        Invoice     StockCode Description  Quantity         InvoiceDate  Price  \
# 75138   496250  gift_0001_60         NaN         3 2010-01-29 16:17:00    0.0
# 298843  518490  gift_0001_60         NaN        10 2010-08-09 12:29:00    0.0
#
#         Customer ID         Country
# 75138           NaN  United Kingdom
# 298843          NaN  United Kingdom

# %%
df[df["StockCode"].str.contains("^gift_0001_20")].head(5)
# Out:
#       Invoice     StockCode                         Description  Quantity  \
# 32048  491971  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         2
# 40905  492782  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 45213  493404  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 75097  496247  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 96283  498443  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
#
#               InvoiceDate  Price  Customer ID         Country
# 32048 2009-12-14 18:37:00  17.39          NaN  United Kingdom
# 40905 2009-12-18 17:06:00  17.39          NaN  United Kingdom
# 45213 2009-12-23 15:30:00  17.39          NaN  United Kingdom
# 75097 2010-01-29 16:11:00  17.02          NaN  United Kingdom
# 96283 2010-02-19 09:49:00  17.02          NaN  United Kingdom

# %%
df[df["StockCode"].str.contains("^gift_0001_40")].head(5)
# Out:
#        Invoice     StockCode                         Description  Quantity  \
# 75137   496248  gift_0001_40                                 NaN         3
# 298847  518492  gift_0001_40                                 NaN        10
# 299652  518579  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00         1
# 407443  528382  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00         1
#
#                InvoiceDate  Price  Customer ID         Country
# 75137  2010-01-29 16:17:00   0.00          NaN  United Kingdom
# 298847 2010-08-09 12:30:00   0.00          NaN  United Kingdom
# 299652 2010-08-10 12:08:00  31.35          NaN  United Kingdom
# 407443 2010-10-21 18:01:00  34.04          NaN  United Kingdom

# %%
df[df["StockCode"].str.contains("^GIFT")].head(5)
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 83304  497107      GIFT         NaN        -9 2010-02-05 15:18:00    0.0
#
#        Customer ID         Country
# 83304          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - gift: Purchases with gift cards, no customer data -- Exclude
# - GIFT: Invalid -- Exclude

# %%
df[df["StockCode"].str.contains("^PADS")].head(5)
# Out:
#       Invoice StockCode                 Description  Quantity  \
# 62299  494914      PADS  PADS TO MATCH ALL CUSHIONS         1
# 74731  496222      PADS  PADS TO MATCH ALL CUSHIONS         1
# 77702  496473      PADS  PADS TO MATCH ALL CUSHIONS         1
# 79794  496643      PADS  PADS TO MATCH ALL CUSHIONS         1
# 90798  497935      PADS  PADS TO MATCH ALL CUSHIONS         1
#
#               InvoiceDate  Price  Customer ID         Country
# 62299 2010-01-19 17:04:00  0.001      16705.0  United Kingdom
# 74731 2010-01-29 13:53:00  0.001      13583.0  United Kingdom
# 77702 2010-02-01 15:38:00  0.001      17350.0  United Kingdom
# 79794 2010-02-03 11:58:00  0.001      13408.0  United Kingdom
# 90798 2010-02-15 10:47:00  0.001      13408.0  United Kingdom

# %% [markdown]
# OBSERVATION:
# - PADS: Looks like a legit stock code for padding -- Include

# %%
df[df["StockCode"].str.contains("^SP1002")].head(5)
# Out:
#        Invoice StockCode             Description  Quantity  \
# 377066  525772    SP1002  KID'S CHALKBOARD/EASEL         1
# 377387  525837    SP1002  KID'S CHALKBOARD/EASEL         4
# 426694  530135    SP1002                     NaN       -27
#
#                InvoiceDate  Price  Customer ID         Country
# 377066 2010-10-07 11:12:00   2.95      12748.0  United Kingdom
# 377387 2010-10-07 12:23:00   2.95      17841.0  United Kingdom
# 426694 2010-11-01 15:33:00   0.00          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - SP1002: Looks like a special request item, only 2 transactions -- Exclude for now

# %%
df[df["StockCode"].str.contains("^ADJUST2")].head(5)
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 249672  513564   ADJUST2  Adjustment by Peter on Jun 25 2010          1
# 249673  513566   ADJUST2  Adjustment by Peter on Jun 25 2010          1
# 249674  513565   ADJUST2  Adjustment by Peter on Jun 25 2010          1
#
#                InvoiceDate   Price  Customer ID         Country
# 249672 2010-06-25 14:15:00  300.13      17050.0  United Kingdom
# 249673 2010-06-25 14:15:00  358.47      17364.0  United Kingdom
# 249674 2010-06-25 14:15:00   72.45      16422.0  United Kingdom

# %% [markdown]
# OBSERVATION:
# - ADJUST2: Looks like manual account adjustments by admins -- Exclude for now

# %%
df[df["StockCode"].str.contains("^AMAZONFEE")].head(5)
# Out:
#         Invoice  StockCode Description  Quantity         InvoiceDate  \
# 440688  C531400  AMAZONFEE  AMAZON FEE        -1 2010-11-08 10:08:00
# 440698   531411  AMAZONFEE  AMAZON FEE         1 2010-11-08 10:11:00
# 517452  C537600  AMAZONFEE  AMAZON FEE        -1 2010-12-07 12:41:00
# 517953  C537630  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:04:00
# 517955   537632  AMAZONFEE  AMAZON FEE         1 2010-12-07 15:08:00
#
#            Price  Customer ID         Country
# 440688   6706.71          NaN  United Kingdom
# 440698   6706.71          NaN  United Kingdom
# 517452      1.00          NaN  United Kingdom
# 517953  13541.33          NaN  United Kingdom
# 517955  13541.33          NaN  United Kingdom

# %% [markdown]
# OBSERVATION:
# - AMAZONFEE: Looks like Amazon shipping fees-- Exclude for now

# %% [markdown]
# ## Data Cleaning

# %%
cleaned_df = df.copy()

# %%
cleaned_df["Invoice"] = cleaned_df["Invoice"].astype("str")

maskI = (
    cleaned_df["Invoice"].str.match("^\\d{6}$") == True
)

cleaned_df = cleaned_df[maskI]

cleaned_df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
cleaned_df["StockCode"] = cleaned_df["StockCode"].astype("str")

maskS = (
    (cleaned_df["StockCode"].str.match("^\\d{5}$") == True)
    | (cleaned_df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == True)
    | (cleaned_df["StockCode"].str.match("^PADS$") == True)
)

cleaned_df = cleaned_df[maskS]

cleaned_df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
cleaned_df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2880
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    106459
# Country             0
# dtype: int64

# %%
cleaned_df.dropna(subset=["Customer ID"], inplace=True)

# %%
cleaned_df.shape
# Out:
# (406337, 8)

# %%
cleaned_df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  406337.000000                      406337  406337.000000  406337.000000
# mean       13.619099  2010-07-01 10:11:06.543287       2.991462   15373.632992
# min         1.000000         2009-12-01 07:45:00       0.000000   12346.000000
# 25%         2.000000         2010-03-26 14:01:00       1.250000   14004.000000
# 50%         5.000000         2010-07-09 15:48:00       1.950000   15326.000000
# 75%        12.000000         2010-10-14 17:09:00       3.750000   16814.000000
# max     19152.000000         2010-12-09 20:01:00     295.000000   18287.000000
# std        97.000659                         NaN       4.285876    1677.365907

# %%
len(cleaned_df[cleaned_df["Price"] == 0])
# Out:
# 28

# %%
cleaned_df = cleaned_df[cleaned_df["Price"] > 0.0]

# %%
cleaned_df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  406309.000000                      406309  406309.000000  406309.000000
# mean       13.617924  2010-07-01 10:14:25.869572       2.991668   15373.722268
# min         1.000000         2009-12-01 07:45:00       0.001000   12346.000000
# 25%         2.000000         2010-03-26 14:01:00       1.250000   14006.000000
# 50%         5.000000         2010-07-09 15:48:00       1.950000   15326.000000
# 75%        12.000000         2010-10-14 17:09:00       3.750000   16814.000000
# max     19152.000000         2010-12-09 20:01:00     295.000000   18287.000000
# std        96.998833                         NaN       4.285951    1677.329470

# %%
df[df.duplicated(keep=False)].head()
# Out:
#     Invoice StockCode                        Description  Quantity  \
# 362  489517     21913     VINTAGE SEASIDE JIGSAW PUZZLES         1
# 363  489517     21912           VINTAGE SNAKES & LADDERS         1
# 365  489517     21821   GLITTER STAR GARLAND WITH BELLS          1
# 367  489517     22319  HAIRCLIPS FORTIES FABRIC ASSORTED        12
# 368  489517     22130   PARTY CONE CHRISTMAS DECORATION          6
#
#             InvoiceDate  Price  Customer ID         Country
# 362 2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 363 2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 365 2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 367 2009-12-01 11:34:00   0.65      16329.0  United Kingdom
# 368 2009-12-01 11:34:00   0.85      16329.0  United Kingdom

# %%
len(cleaned_df)/len(df)
# Out:
# 0.7732429238325965

# %% [markdown]
# ## Feature Engineering
